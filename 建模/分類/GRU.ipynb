# %%
import pandas as pd
data = pd.read_csv('traindata2')

# %%
alltext = []
for i in data['text']:
    tl = i.split(' ')
    alltext.append(tl)

# %%
from gensim.corpora import Dictionary
dct = Dictionary(alltext)

# %%
from keras.preprocessing import sequence
X = [dct.doc2idx(txt) for txt in alltext]
X =sequence.pad_sequences(X, padding='post', value=len(dct))

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test= train_test_split(X,data.iloc[:,-1],test_size=0.3,random_state=0)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Embedding
from keras.layers import GRU
from keras.layers import Dropout

# %%
model = Sequential()
model.add(Embedding(len(dct)+1,128,input_length=X.shape[1]))
model.add(GRU(128))
model.add(Dense(4,activation="softmax"))
model.summary()
model.compile(loss="sparse_categorical_crossentropy",optimizer="adam",metrics=["accuracy"])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 1337, 128)         3421184
#
#  gru (GRU)                   (None, 128)               99072
#
#  dense (Dense)               (None, 4)                 516
#
# =================================================================
# Total params: 3,520,772
# Trainable params: 3,520,772
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x=X_train,y=y_train, validation_split=0.1, epochs=10, verbose=1)
# Out:
# Epoch 1/10
# 9/9 [==============================] - 16s 1s/step - loss: 1.3870 - accuracy: 0.2682 - val_loss: 1.3882 - val_accuracy: 0.1667
# Epoch 2/10
# 9/9 [==============================] - 12s 1s/step - loss: 1.3771 - accuracy: 0.2989 - val_loss: 1.4021 - val_accuracy: 0.1667
# Epoch 3/10
# 9/9 [==============================] - 12s 1s/step - loss: 1.3812 - accuracy: 0.2989 - val_loss: 1.4166 - val_accuracy: 0.1667
# Epoch 4/10
# 9/9 [==============================] - 12s 1s/step - loss: 1.3823 - accuracy: 0.3027 - val_loss: 1.4036 - val_accuracy: 0.1667
# Epoch 5/10
# 9/9 [==============================] - 12s 1s/step - loss: 1.3781 - accuracy: 0.3027 - val_loss: 1.3904 - val_accuracy: 0.1667
# Epoch 6/10
# 9/9 [==============================] - 12s 1s/step - loss: 1.3773 - accuracy: 0.3027 - val_loss: 1.3799 - val_accuracy: 0.1667
# Epoch 7/10
# 9/9 [==============================] - 13s 1s/step - loss: 1.3758 - accuracy: 0.3027 - val_loss: 1.3727 - val_accuracy: 0.1667
# Epoch 8/10
# 9/9 [==============================] - 12s 1s/step - loss: 1.3761 - accuracy: 0.3027 - val_loss: 1.3777 - val_accuracy: 0.1667
# Epoch 9/10
# 9/9 [==============================] - 12s 1s/step - loss: 1.3757 - accuracy: 0.3027 - val_loss: 1.3799 - val_accuracy: 0.1667
# Epoch 10/10
# 9/9 [==============================] - 13s 2s/step - loss: 1.3761 - accuracy: 0.3027 - val_loss: 1.3771 - val_accuracy: 0.1667

# %%
model.evaluate(X_test, y_test ,batch_size=10)
# Out:
# 13/13 [==============================] - 2s 157ms/step - loss: 1.4085 - accuracy: 0.2000
# [1.4085071086883545, 0.20000000298023224]

# %%
model.predict(X_test)
# Out:
# array([[0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.214332  , 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.214332  , 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.214332  , 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.214332  , 0.2816782 , 0.200645  ],
#        [0.30334488, 0.214332  , 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.214332  , 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.214332  , 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.214332  , 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.214332  , 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.214332  , 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334485, 0.21433197, 0.28167817, 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.214332  , 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.214332  , 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.214332  , 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.214332  , 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ],
#        [0.30334488, 0.21433197, 0.2816782 , 0.200645  ]], dtype=float32)

# %%
from keras.models import load_model
model.save('kerassave')
newmodel = load_model('kerassave')
