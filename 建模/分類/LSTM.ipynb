# %%
import pandas as pd
data = pd.read_csv('traindata2')

# %%
alltext = []
for i in data['text']:
    tl = i.split(' ')
    alltext.append(tl)

# %%
from gensim.corpora import Dictionary
dct = Dictionary(alltext)

# %%
from keras.preprocessing import sequence
X = [dct.doc2idx(txt) for txt in alltext]
X =sequence.pad_sequences(X, padding='post', value=len(dct))

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test= train_test_split(X,data.iloc[:,-1],test_size=0.3,random_state=0)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Embedding
from keras.layers import LSTM
from keras.layers import Dropout

# %%
model = Sequential()
model.add(Embedding(len(dct)+1,128,input_length=X.shape[1]))
model.add(LSTM(128))
model.add(Dense(4,activation="softmax"))
model.summary()
model.compile(loss="sparse_categorical_crossentropy",optimizer="adam",metrics=["accuracy"])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 1337, 128)         3421184
#
#  lstm (LSTM)                 (None, 128)               131584
#
#  dense (Dense)               (None, 4)                 516
#
# =================================================================
# Total params: 3,553,284
# Trainable params: 3,553,284
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x=X_train,y=y_train, validation_split=0.1, epochs=10, verbose=1)
# Out:
# Epoch 1/10
# 9/9 [==============================] - 21s 2s/step - loss: 1.3913 - accuracy: 0.2069 - val_loss: 1.3783 - val_accuracy: 0.1667
# Epoch 2/10
# 9/9 [==============================] - 18s 2s/step - loss: 1.3787 - accuracy: 0.3027 - val_loss: 1.3943 - val_accuracy: 0.1667
# Epoch 3/10
# 9/9 [==============================] - 17s 2s/step - loss: 1.3760 - accuracy: 0.3027 - val_loss: 1.4137 - val_accuracy: 0.1667
# Epoch 4/10
# 9/9 [==============================] - 17s 2s/step - loss: 1.3850 - accuracy: 0.3027 - val_loss: 1.4157 - val_accuracy: 0.1667
# Epoch 5/10
# 9/9 [==============================] - 17s 2s/step - loss: 1.3844 - accuracy: 0.3027 - val_loss: 1.3716 - val_accuracy: 0.1667
# Epoch 6/10
# 9/9 [==============================] - 16s 2s/step - loss: 1.3771 - accuracy: 0.3027 - val_loss: 1.3735 - val_accuracy: 0.1667
# Epoch 7/10
# 9/9 [==============================] - 16s 2s/step - loss: 1.3756 - accuracy: 0.3027 - val_loss: 1.3796 - val_accuracy: 0.1667
# Epoch 8/10
# 9/9 [==============================] - 17s 2s/step - loss: 1.3760 - accuracy: 0.3027 - val_loss: 1.3798 - val_accuracy: 0.1667
# Epoch 9/10
# 9/9 [==============================] - 17s 2s/step - loss: 1.3760 - accuracy: 0.3027 - val_loss: 1.3863 - val_accuracy: 0.1667
# Epoch 10/10
# 9/9 [==============================] - 16s 2s/step - loss: 1.3749 - accuracy: 0.3027 - val_loss: 1.3762 - val_accuracy: 0.1667

# %%
model.evaluate(X_test, y_test ,batch_size=10)
# Out:
# 13/13 [==============================] - 3s 235ms/step - loss: 1.4095 - accuracy: 0.2000
# [1.409527063369751, 0.20000000298023224]

# %%
model.predict(X_test)
# Out:
# array([[0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036226, 0.20857067, 0.27348983, 0.21757725],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036226, 0.20857067, 0.27348983, 0.21757725],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036226, 0.20857067, 0.27348983, 0.21757725],
#        [0.30036226, 0.20857067, 0.27348983, 0.21757725],
#        [0.30036226, 0.20857067, 0.27348983, 0.21757725],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036226, 0.20857067, 0.27348983, 0.21757725],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036226, 0.20857067, 0.27348983, 0.21757725],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036226, 0.20857067, 0.27348983, 0.21757725],
#        [0.30036226, 0.20857067, 0.27348983, 0.21757725],
#        [0.30036226, 0.20857067, 0.27348983, 0.21757725],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036226, 0.20857067, 0.27348983, 0.21757725],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036226, 0.20857067, 0.27348983, 0.21757725],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036226, 0.20857067, 0.27348983, 0.21757725],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036226, 0.20857067, 0.27348983, 0.21757725],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036226, 0.20857067, 0.27348983, 0.21757725],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036226, 0.20857067, 0.27348983, 0.21757725],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722],
#        [0.30036223, 0.20857066, 0.2734898 , 0.21757722]], dtype=float32)

# %%
from keras.models import load_model
model.save('kerassave')
newmodel = load_model('kerassave')
