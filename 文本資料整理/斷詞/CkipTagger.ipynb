# %%
# 標準安裝
# !pip install -U ckiptagger[tf,gdown]
# CkipTagger是在PyPI上的Python package. 需求：
#   python>=3.6
#   tensorflow>=1.13.1 / tensorflow-gpu>=1.13.1 (其中之一)
#   gdown (非必要，用來從google drive下載模型檔)
# Out:
# ...
#   Using cached gdown-4.2.0-py3-none-any.whl
# ...
#   Using cached typing_extensions-4.0.0-py3-none-any.whl (22 kB)
# ...
#   Using cached tensorflow_estimator-2.7.0-py2.py3-none-any.whl (463 kB)
# ...
#   Using cached protobuf-3.19.1-cp38-cp38-win_amd64.whl (895 kB)
# ...
#   Using cached libclang-12.0.0-py2.py3-none-win_amd64.whl (13.1 MB)
# ...
#   Using cached keras-2.7.0-py2.py3-none-any.whl (1.3 MB)
# ...
#   Using cached tensorflow_io_gcs_filesystem-0.22.0-cp38-cp38-win_amd64.whl (1.5 MB)
# ...
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# ...
#   Using cached tensorboard-2.7.0-py3-none-any.whl (5.8 MB)
# ...
#   Using cached flatbuffers-2.0-py2.py3-none-any.whl (26 kB)
# ...
#   Using cached termcolor-1.1.0-py3-none-any.whl
# ...
#   Using cached absl_py-1.0.0-py3-none-any.whl (126 kB)
# ...
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# ...
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# ...

# %%
from ckiptagger import data_utils, construct_dictionary, WS, POS, NER

# %%
# 下載模型檔
# 下載至 ./data.zip (2GB) 然後解壓縮至 ./data/
# 模型檔可在幾個不同地方下載
# data_utils.download_data_url("./") # iis-ckip 
data_utils.download_data_gdown("./") # gdrive-ckip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1efHsY16pxK0lBD2gYCgCTnv1Swstq771
# To: C:\Users\Tibame_T14\Desktop\CFI101_AIproject\data.zip
#
#   0%|                                                                                      | 0.00/1.88G [00:00<?, ?B/s]
#   0%|                                                                             | 1.05M/1.88G [00:00<04:30, 6.94MB/s]
#   0%|                                                                             | 2.10M/1.88G [00:00<04:20, 7.20MB/s]
#   0%|▏                                                                            | 3.15M/1.88G [00:00<04:15, 7.34MB/s]
#   0%|▏                                                                            | 4.19M/1.88G [00:00<04:13, 7.38MB/s]
#   0%|▏                                                                            | 5.24M/1.88G [00:00<04:12, 7.41MB/s]
# ...

# %%
# 載入模型
# WS、POS、NER，分別是斷詞、詞性標記、命名實體識別
ws = WS("./data")
# pos = POS("./data")
# ner = NER("./data")
# Out:
#   6%|████                                                                     | 106M/1.88G [1:31:02<25:21:54, 19.4kB/s]

# %%
import json

# %%
# 載入資料
with open('./youtube/醫療保健text.json') as f:
    data = json.loads(f.read())

# %%
for file in data.values():
    for name, texts in file.items():
        print(name)
############################### CkipTagger斷詞 ###############################
        word_sentence_list = ws(list(texts))
        for i, sentence in enumerate(texts):
            print(sentence)
            print()
            for word in word_sentence_list[i]:
                print(word, end="/")
            print()
            break
#############################################################################
        break
    break
# Out:
# 10大夢幻甜點開箱，這款好吃到流淚！？甜點控必看_20210914.mp4
# 我是請老大你們知道嗎我是一個非常喜歡吃甜食的人因為有吃一口甜點就可以讓老大心情很好讓我忘記煩惱而且同時只要你能夠去控制亮喔其實是不太會發胖的所以啊這一集有超級稀有沒有來開箱20 21年在網路上最有人氣的甜點看看有哪些是真正好吃的喔實至名歸者是哪一些雷聲大雨
#
# 我/是/請/老大/你們/知道/嗎/我/是/一/個/非常/喜歡/吃/甜食/的/人/因為/有/吃/一/口/甜點/就/可以/讓/老大/心情/很/好/讓/我/忘記/煩惱/而且/同時/只要/你/能夠/去/控制/亮/喔/其實/是/不/太/會/發胖/的/所以/啊/這/一/集/有/超級/稀有沒有/來/開箱/20/ /21年/在/網路/上/最/有/人氣/的/甜點/看看/有/哪些/是/真正/好吃/的/喔/實至名歸/者/是/哪/一些/雷聲/大雨/

# %%
# 釋放記憶體
del ws
del pos
del ner
